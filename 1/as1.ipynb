# %% [markdown]
# # Task 1: Create Normal Headings (5 marks)

# %% [markdown]
# # Level 1 "#"

# %% [markdown]
# ## Level 2 "##"

# %% [markdown]
# ### Level 3 "###"

# %% [markdown]
# #### Level 4 "####"

# %% [markdown]
# ##### Level 5 "#####"

# %% [markdown]
# ###### Level 6 "######"

# %% [markdown]
# ---

# %% [markdown]
# # Task 2: Center a Heading (10 marks)

# %% [markdown]
# <h2 align="center"> Welcome to My Notebook </h2>

# %%
<h2 align="center"> Welcome to My Notebook </h2>

# %% [markdown]
# ---

# %% [markdown]
# # Task 3: Insert an Image (10 marks)

# %% [markdown]
# <img src="https://i0.wp.com/bdtechtalks.com/wp-content/uploads/2021/05/machine-learning-programming.jpg">

# %%
<img src="https://i0.wp.com/bdtechtalks.com/wp-content/uploads/2021/05/machine-learning-programming.jpg">

# %% [markdown]
# ---

# %% [markdown]
# # Task 4: Resize an Image (10 marks)

# %% [markdown]
# <img src="https://i0.wp.com/bdtechtalks.com/wp-content/uploads/2021/05/machine-learning-programming.jpg" width="200">

# %%
<img src="https://i0.wp.com/bdtechtalks.com/wp-content/uploads/2021/05/machine-learning-programming.jpg" width="200">

# %% [markdown]
# ---

# %% [markdown]
# # Task 5: Image + Text Side by Side (15 marks)

# %% [markdown]
# <table>
#     <tr>
#         <td> <img src="https://tk-imperator.kz/upload/resize_cache/iblock/9a6/378_600_1/2twn1w968uefbzqtb5sz3md61o4l0qr6.jpg" </td>
#         <td> <h2> Abai Qunanbayev </h2> </td>
#     </tr>
# </table>

# %%
<table>
    <tr>
        <td> <img src="https://tk-imperator.kz/upload/resize_cache/iblock/9a6/378_600_1/2twn1w968uefbzqtb5sz3md61o4l0qr6.jpg" </td>
        <td> <h2> Abai Qunanbayev </h2> </td>
    </tr>
</table>

# %% [markdown]
# ---

# %% [markdown]
# # Task 6: Display 3 Images Side by Side (15 marks)

# %% [markdown]
# <div align="center">
#     <h2>Қазақтың 3 бәйтерегі</h2>
#     <img src="https://adebiportal.kz/storage/tmp/resize/authors/1200_0_c40514209ba0a907f2260b69e68df6a6.jpg" width="200">
#     <img src="https://qaa.kz/wp-content/uploads/2024/02/IMG_50632709190536-scaled.jpg" width="200">
#     <img src="https://adebiportal.kz/storage/tmp/resize/authors/1200_0_aae291169e4bd5ea4327e2d6d12237fb.jpg" width="200">
# </div>

# %%
<div align="center">
    <h2>Қазақтың 3 бәйтерегі</h2>
    <img src="https://adebiportal.kz/storage/tmp/resize/authors/1200_0_c40514209ba0a907f2260b69e68df6a6.jpg" width="200">
    <img src="https://qaa.kz/wp-content/uploads/2024/02/IMG_50632709190536-scaled.jpg" width="200">
    <img src="https://adebiportal.kz/storage/tmp/resize/authors/1200_0_aae291169e4bd5ea4327e2d6d12237fb.jpg" width="200">
</div>

# %% [markdown]
# ---

# %% [markdown]
# # Task 7: Centered Title with an Image (10 marks)

# %% [markdown]
# <div align="center">
# <h1>My Favorite Animal</h1>
# <img src="https://static01.nyt.com/images/2024/03/05/autossell/00TB-MEOWS/00TB-MEOWS-square640.jpg" width="200">
# </div>

# %%
<div align="center">
<h1>My Favorite Animal</h1>
<img src="https://static01.nyt.com/images/2024/03/05/autossell/00TB-MEOWS/00TB-MEOWS-square640.jpg" width="200">
</div>
