# %% [markdown]
# <h1 align="center"> Practice 1 </h1>

# %% [markdown]
# <div class="alert alert" role="alert">
#   <h4 class="alert-heading">Instructions</h4>
#   <ul>
#     <li>Nuridin should KNOW the HTML to edit documents in jupiter</li>
#   </ul>
#   <ol>
#     <li> To learn JAVA </li>
#
#   </ol>
#   </div>

# %% [markdown]
# [Kbtu](www.wsp.kbtu.kz)

# %% [markdown]
# <div align="center"> 👨🏻‍💻this is emoji <div>

# %% [markdown]
# # 1. Headings

# %% [markdown]
# # H1
# ## H2
# ### H3
# #### H4
# ##### H5
# ###### H6

# %% [markdown]
# <div align="center" sixe:40> This is centered text with method div </div>
# <h4 align="center"> This is centered text with method h1 </h4>

# %% [markdown]
# *italic*
#
# __bold__
#
# **bold**
#
# ~~Canceled~~

# %% [markdown]
# To-do:
#   1. Learn HTML
#   2. Learn CSS
#   3. Learn JavaScript
#   4. Learn JAVA
#   5. Learn Python

# %% [markdown]
# This is [kbtu](www.wsp.kbtu.kz)'s website

# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpsSFITGtd3AmlgL5mcjh7xf7A-QJP83X7tA&s" alt="text" width="200" height="150">

# %% [markdown]
# <table>
# <tr>
# <td> <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpsSFITGtd3AmlgL5mcjh7xf7A-QJP83X7tA&s" alt="text" width="200" height="150"> </td>
# <td> This is Machine learning </td>
# </tr>
# </table>

# %% [markdown]
# <p align="center">
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpsSFITGtd3AmlgL5mcjh7xf7A-QJP83X7tA&s" alt="text" width="200" height="150">
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpsSFITGtd3AmlgL5mcjh7xf7A-QJP83X7tA&s" alt="text" width="200" height="150">
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpsSFITGtd3AmlgL5mcjh7xf7A-QJP83X7tA&s" alt="text" width="200" height="150">
# </p>

# %% [markdown]
# ---

# %% [markdown]
# ```
# def greet(name):
#     return f"Hello, {name}!"

# %% [markdown]
# <table>
#   <tr>
#     <th> Name </th>
#     <th> Surname </th>
#     <th> Age </th>
#   </tr>
#   <tr>
#     <td> Nuridin </td>
#     <td> Abdukarimov </td>
#     <td> 18 </td>
#   </tr>
#   <tr>
#     <td> John </td>
#     <td> Doe </td>
#     <td> 25 </td>
#   </tr>
#  </table>

# %% [markdown]
# ---

# %% [markdown]
# > This is block code

# %% [markdown]
# 1. Java
#     - Basics
#     - OOP
# 2. Python
#     - Basics
#     - Data Science

# %% [markdown]
# Task list:
# - [x] Learn HTML
# - [x] Learn CSS
# - [ ] Learn JavaScript
# - [ ] Learn JAVA
# - [ ] Learn Python

# %% [markdown]
# <div style="background-color:red;> This is a colored text box </div>

# %% [markdown]
# # Adding the emojis with control + command + space
# <div align = "center"> 😀 😃 😄</div>

# %% [markdown]
# <div style="background-color: yellow; color: black"> This is a colored div box </div>

# %% [markdown]
# ## Latex
# $$
# \int_{a}^{b} x^2 \,dx = \left[ \frac{x^3}{3} \right]_{a}^{b}
# $$
