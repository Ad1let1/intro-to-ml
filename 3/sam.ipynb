# %%
have_missing = ['age', 'embark_town', 'embarked', 'deck]
for col in have_missing:
    miss_p = df[col].isna().sum()/len(df)*100
    print(f"{col} has {miss_p} missing values")

# %%
df.drop(columns=['deck'], inplace=True);

# %%
df.isna().sum() // check for null
df.duplicated().sum() // check for duplicates
